# %%
from pydantic import BaseModel,Field
from langgraph.graph import StateGraph,START,END
from langgraph.types import Send
from typing import TypedDict, List, Optional, Literal, Annotated
import operator
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
# llm=ChatGroq(model="openai/gpt-oss-120b")
from openai import OpenAI
from langchain_openai import ChatOpenAI
# create client with dummy API key
llm = ChatOpenAI(model="gpt-4o-mini")
    

# t=llm.invoke("hey there")
# print(t)
from langchain_core.messages import SystemMessage, HumanMessage

# %%
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"
    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # keep if Tavily provides; DO NOT rely on it
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)

    # reducer/image
    merged_md: str
    md_with_placeholders: str
    image_specs: List[dict]

    final: str

# %%
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- If user asked for "last week/this week/latest", reflect that constraint IN THE QUERIES.
"""
class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    queries: List[str] = Field(default_factory=list)

def router_node(state:State)->dict:
    topic=state["topic"]
    decider=llm.with_structured_output(RouterDecision)
    decision=decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic:{topic}"),
        ]
    )
    return{
        "need_research":decision.needs_research,
        "mode":decision.mode,
        "queries":decision.queries,
    }
def route_next(state:State)->str:
    return "research" if state ["needs_research"] else "orchestrator"

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized

RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- If a published date is explicitly present in the result payload, keep it as YYYY-MM-DD.
  If missing or unclear, set published_at=null. Do NOT guess.
- Keep snippets short.
- Deduplicate by URL.
"""   
def research_node(state:State)->dict:
    queries=(state.get("queries",[]) or [])
    max_results=6
    raw_results:List[dict]=[]
    for q in queries:
        raw_results.extend(_tavily_search(q,max_results=max_results))
    if not raw_results:
        return {"evidence":[]}
    extractor=llm.with_structured_output(EvidencePack)
    pack=extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(content=f"Raw results:\n{raw_results}"),
        ]
    )
    dedup={}
    for e in pack.evidence:
        if e.rul:
            dedup[e.rul]=e
    return {"evidence":list(dedup.values())}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book:
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)

    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}"
                )
            ),
        ]
    )

    return {"plan": plan}

# %%
def fanout(state: State):
    return [
        Send(
            "worker",
            {
                "task": task,
                "topic": state["topic"],
                "plan": state["plan"],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard:
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book:
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true:
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""
def worker_node(payload: dict) -> dict:

    # -------- normalize task --------
    raw_task = payload.get("task")
    if raw_task is None:
        raise ValueError("worker_node: task is missing")

    if isinstance(raw_task, Task):
        task = raw_task
    elif isinstance(raw_task, dict):
        task = Task(**raw_task)
    else:
        raise TypeError(f"worker_node: task has invalid type {type(raw_task)}")

    # -------- normalize plan --------
    raw_plan = payload.get("plan")
    if raw_plan is None:
        raise ValueError("worker_node: plan is missing")

    if isinstance(raw_plan, Plan):
        plan = raw_plan
    elif isinstance(raw_plan, dict):
        plan = Plan(**raw_plan)
    else:
        raise TypeError(f"worker_node: plan has invalid type {type(raw_plan)}")

    # -------- normalize evidence --------
    evidence = []
    for e in payload.get("evidence", []):
        if isinstance(e, EvidenceItem):
            evidence.append(e)
        elif isinstance(e, dict):
            evidence.append(EvidenceItem(**e))
        else:
            raise TypeError(f"worker_node: evidence item has invalid type {type(e)}")

    # -------- rest of logic --------
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}"
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    return {"sections": [(task.id, section_md)]}

# %%
import re

def safe_md_filename(title: str) -> str:
    """
    Make a Windows-safe markdown filename from a blog title.
    """
    safe = re.sub(r'[\\/:*?"<>|]', "", title)
    safe = safe.strip().replace(" ", "_")
    if not safe.lower().endswith(".md"):
        safe += ".md"
    return safe

class ImageSpec(BaseModel):
    placeholder: str = Field(..., description="e.g. [[IMAGE_1]]")
    filename: str = Field(..., description="Save under images/, e.g. qkv_flow.png")
    alt: str
    caption: str
    prompt: str = Field(..., description="Prompt to send to the image model.")
    size: Literal["1024x1024", "1024x1536", "1536x1024"] = "1024x1024"
    quality: Literal["low", "medium", "high"] = "medium"


class GlobalImagePlan(BaseModel):
    md_with_placeholders: str
    images: List[ImageSpec] = Field(default_factory=list)
def merge_content(state: State) -> dict:
    plan = state["plan"]

    ordered_sections = [
        md for _, md in sorted(state["sections"], key=lambda x: x[0])
    ]
    body = "\n\n".join(ordered_sections).strip()
    merged_md = f"# {plan.blog_title}\n\n{body}\n"

    return {"merged_md": merged_md}
DECIDE_IMAGES_SYSTEM = """You are an expert technical editor.
Decide if images/diagrams are needed for THIS blog.

Rules:
- Max 3 images total.
- Each image must materially improve understanding.
- Insert placeholders exactly: [[IMAGE_1]], [[IMAGE_2]], [[IMAGE_3]].
- If no images needed: md_with_placeholders must equal input and images=[].
Return strictly GlobalImagePlan.
"""
def decide_images(state: State) -> dict:
    planner = llm.with_structured_output(GlobalImagePlan)

    merged_md = state["merged_md"]
    plan = state["plan"]
    assert plan is not None

    image_plan = planner.invoke(
        [
            SystemMessage(content=DECIDE_IMAGES_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Topic: {state['topic']}\n\n"
                    "Insert placeholders + propose image prompts.\n\n"
                    f"{merged_md}"
                )
            ),
        ]
    )

    return {
        "md_with_placeholders": image_plan.md_with_placeholders,
        "image_specs": [img.model_dump() for img in image_plan.images],
    }
from pathlib import Path

def generate_and_place_images(state: State) -> dict:
    plan = state["plan"]
    assert plan is not None

    md = state.get("md_with_placeholders") or state["merged_md"]
    image_specs = state.get("image_specs", []) or []

    # ✅ SAFE filename
    md_filename = safe_md_filename(plan.blog_title)

    # If no images → just write markdown
    if not image_specs:
        Path(md_filename).write_text(md, encoding="utf-8")
        return {"final": md}

    images_dir = Path("images")
    images_dir.mkdir(exist_ok=True)

    for spec in image_specs:
        placeholder = spec["placeholder"]
        img_filename = spec["filename"]
        out_path = images_dir / img_filename

        if not out_path.exists():
            try:
                img_bytes = _gemini_generate_image_bytes(spec["prompt"])
                out_path.write_bytes(img_bytes)
            except Exception as e:
                fallback = (
                    f"> **[IMAGE GENERATION FAILED]** {spec.get('caption','')}\n>\n"
                    f"> **Alt:** {spec.get('alt','')}\n>\n"
                    f"> **Prompt:** {spec.get('prompt','')}\n>\n"
                    f"> **Error:** {e}\n"
                )
                md = md.replace(placeholder, fallback)
                continue

        img_md = f"![{spec['alt']}](images/{img_filename})\n*{spec['caption']}*"
        md = md.replace(placeholder, img_md)

    Path(md_filename).write_text(md, encoding="utf-8")
    return {"final": md}

# %%
reducer_graph = StateGraph(State)
reducer_graph.add_node("merge_content", merge_content)
reducer_graph.add_node("decide_images", decide_images)
reducer_graph.add_node("generate_and_place_images", generate_and_place_images)
reducer_graph.add_edge(START, "merge_content")
reducer_graph.add_edge("merge_content", "decide_images")
reducer_graph.add_edge("decide_images", "generate_and_place_images")
reducer_graph.add_edge("generate_and_place_images", END)
reducer_subgraph = reducer_graph.compile()

reducer_subgraph

# %%
# -----------------------------
# 9) Build main graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_subgraph)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()
app

# %%
from datetime import date, timedelta
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,
            "sections": [],
            "merged_md": "",
            "md_with_placeholders": "",
            "image_specs": [],
            "final": "",
        }
    )

    return out

# %%
run("why india is so behind to china")
# Out:
# {'topic': 'why india is so behind to china',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title="Comparative Analysis: India's Development Trajectory vs. China's", audience='Developers, Economists, and Policy Makers', tone='Analytical', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Assessing Historical Economic Policies', goal="Understand how historical economic policies have shaped India's growth trajectory compared to China's.", bullets=["Review India's post-independence economic policies focusing on self-reliance and protectionism.", "Examine China's economic reforms initiated in the late 1970s that led to market liberalization.", 'Highlight significant differences in state involvement in the economy between both countries.'], target_words=300, tags=['economics', 'history'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Evaluating Infrastructure Development', goal='Explore the differences in infrastructure development that impact economic growth between India and China.', bullets=['Analyze the scale and quality of transportation networks in both countries, focusing on investment in roads, railways, and ports.', 'Investigate urbanization rates and how infrastructure supports industrialization in each country.', 'Discuss the impact of power supply reliability and telecommunications readiness on business growth.'], target_words=400, tags=['infrastructure', 'development'], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Understanding Human Capital Development', goal='Examine how education and skill development contribute to economic differences between India and China.', bullets=['Compare literacy rates and educational attainment levels, and their effects on workforce capability.', 'Evaluate vocational training programs and their integration into economic sectors in both countries.', 'Discuss public health and its implications on human capital productivity and workforce participation.'], target_words=350, tags=['education', 'human capital'], requires_research=False, requires_citations=False, requires_code=False), Task(id=4, title='Analyzing Governance and Bureaucratic Efficiency', goal='Assess how governance and bureaucratic efficiency impact economic progress in India and China.', bullets=['Explore how government effectiveness and corruption perceptions differ in both countries.', 'Focus on the speed of decision-making processes in infrastructure and investment approvals.', 'Investigate the role of central versus local government dynamics in economic initiatives.'], target_words=300, tags=['governance', 'bureaucracy'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Technical Innovation and Investment Climate', goal="Investigate the role of technological innovation and foreign direct investment in both countries' economic growth.", bullets=['Analyze the level of support for startups and innovation ecosystems in each country.', 'Examine foreign direct investment policies and incentives, comparing ease of doing business rankings.', "Discuss impact of government initiatives like Make in India vs. China's tech advancement strategies."], target_words=400, tags=['innovation', 'investment'], requires_research=False, requires_citations=False, requires_code=False), Task(id=6, title='Examining Social and Cultural Factors', goal='Understand how social and cultural factors contribute to economic divergence between India and China.', bullets=['Explore the role of socio-cultural attitudes towards entrepreneurship in each country.', 'Analyze demographic trends, including population growth and aging populations.', 'Discuss the impact of gender roles on economic participation and workforce equality.'], target_words=350, tags=['society', 'culture'], requires_research=False, requires_citations=False, requires_code=False), Task(id=7, title='Identifying Future Opportunities and Challenges', goal='Identify the future opportunities and challenges that both countries face i ...
#  'sections': [(1,
#    "## Assessing Historical Economic Policies\n\nIndia's economic policies post-independence were largely characterized by a focus on self-reliance and protectionism. This approach aimed to build a robust domestic economy shielded from foreign competition. Key aspects included the establishment of a licensing regime, public sector dominance, and import substitution strategies. However, this protectionist framework often stifled growth, leading to inefficiencies and a slow rate of industrialization.\n\nIn contrast, China's economic reforms, which began in the late 1970s under Deng Xiaoping, marked a radical shift towards market liberalization. These reforms dismantled the centralized planning system and allowed for increased foreign investment, private enterprise, and a focus on export-led growth. The establishment of Special Economic Zones (SEZs) encouraged global trade participation and technology transfer, fundamentally transforming China’s economic landscape.\n\nA crucial point of difference lies in the state involvement in the economy. In India, the government played a restrictive role, often portraying the private sector as a secondary player. Conversely, China embraced a more dynamic approach where the state acted as a catalyst, promoting both public and private sectors while retaining tight control over strategic industries. This dual strategy enabled rapid growth and adaptability in response to global economic changes.\n\nAs a result of these historical economic policies, India's growth has lagged behind China's. The reliance on protectionism restrained competitive advantage, while China's liberalization fostered innovation and productivity. Understanding these contrasting strategies is critical for policymakers and economists as they work to navigate India's future economic development. The lessons learned from these historical contexts will be essential in devising effective policy frameworks that can bolster India's growth trajectory."),
#   (2,
#    "## Evaluating Infrastructure Development\n\nInfrastructure development plays a crucial role in shaping the economic growth trajectory of nations. When comparing India and China, significant differences in the scale and quality of transportation networks are evident, which profoundly impact business operations and economic activity.\n\nChina has massively invested in its transportation infrastructure, resulting in an extensive and high-quality network of roads, railways, and ports. The country boasts the longest high-speed rail network in the world, enabling rapid movement of goods and people across vast distances. This network is complemented by an efficient system of roads and significant investment in port facilities, which enhances China’s capacity for international trade. Consequently, these advancements have facilitated industrial growth, ensuring swift access to markets and resources.\n\nConversely, India’s transportation infrastructure lags behind in both scale and quality. Although India has made strides in improving its road and railway networks, challenges remain in maintenance and expansion. Road congestion and inadequate rail connectivity often hinder the efficient movement of goods. Ports, which are vital for international trade, also require modernization to handle increasing cargo volumes. This disparity in infrastructure limits India's ability to compete effectively on a global scale.\n\nUrbanization rates further highlight the differences in development strategies between the two nations. China's rapid urbanization has been underpinned by significant government investment in infrastructure, enabling cities to support industrialization effectively. Urban centers in China have become hubs of economic activity, equipped with modern facilities and services that attract businesses and investments. In contrast, India's urbanization has faced challenges such as inadequate infrastructure and planning. As cities expand, the strain on existing infrastructure often leads to inefficiencies that impede economic growth.\n\nFurthermore, the reliability of power supply and telecommunications readiness are essential components of a robust infrastructure. In China, the government's focus on developing a stable power grid and modern telecommunications has fostered a conducive environment for business growth. Companies benefit from reliable electricity and cutting-edge communication technologies, allowing them to operate efficiently. In India, however, power outages are still relatively common, with a significant proportion of the population lacking access to consistent electricity. Telecommunications infrastructure, while improving, is unevenly distributed, impacting the growth potential of businesses, especially in rural areas.\n\nIn summary, the disparities in transportation networks, urbanization support, and essential utilities between India and China illustrate the challenges that India faces in catching up economically. Progress in these areas will be crucial for India to enhance its industrial capabilities and strengthen its position in the global economy."),
#   (3,
#    "## Understanding Human Capital Development\n\nHuman capital development plays a crucial role in the economic trajectories of countries, especially concerning education, skill development, and public health. When we compare India and China, the disparities in these areas significantly contribute to their varying economic progress.\n\n### Literacy Rates and Educational Attainment\n\nLiteracy rates and educational attainment levels serve as foundational pillars for workforce capability. According to recent statistics, China's literacy rate exceeds 96%, while India's is around 74%. This fundamental difference facilitates higher levels of educational attainment in China, where more than 50% of the population has completed higher secondary education. In contrast, India's educational system struggles with high dropout rates, particularly in rural areas. These disparities manifest in the workforce; a more educated and skilled workforce enhances productivity, innovation, and economic growth.\n\n### Vocational Training Programs\n\nVocational training programs are another critical aspect influencing human capital development. China has effectively integrated vocational training into its economic sectors, promoting skill development aligned with labor market needs. The alignment between education and economic demand helps China produce a workforce that is ready for both manufacturing and technology-driven industries. Conversely, India has made strides through initiatives like the Skill India Mission; however, the implementation and reach of these programs vary significantly. Many graduates from vocational training programs struggle to find adequate job placements, indicating a disconnect between training and real workforce requirements.\n\n### Public Health Implications\n\nPublic health significantly affects human capital productivity and workforce participation. China invests heavily in healthcare infrastructure, leading to better health outcomes, lower disease burden, and increased life expectancy. In comparison, India's public health system faces challenges, including inadequate access to healthcare services and higher prevalence of malnutrition among children. Poor health hampers workforce participation, as unhealthy individuals are less likely to contribute effectively to economic activities. This results not only in a decline in productivity but also in higher healthcare costs for families and the government.\n\nIn conclusion, the combined effect of literacy, vocational training, and public health illustrates why India currently lags behind China in economic development. Addressing these human capital challenges is essential for India to enhance its workforce capabilities, thereby fostering economic growth and improving living standards."),
#   (4,
#    "## Analyzing Governance and Bureaucratic Efficiency\n\nGovernance and bureaucratic efficiency play critical roles in shaping economic trajectories, particularly in contrasting contexts like India and China. Understanding the differences in government effectiveness and perceptions of corruption reveals why China has often outpaced India in economic progress.\n\nIn China, the government's centralized control allows for more streamlined decision-making. The ruling Communist Party prioritizes economic growth and has a track record of rapid, effective policy implementation. Conversely, India's multi-tiered governance system often results in bureaucratic delays and red tape. The perception of widespread corruption in India further complicates efforts to align public policy with economic objectives. According to various studies, many investors cite corruption as a barrier to business, making them hesitant to commit to long-term investments in the Indian market.\n\nAnother significant aspect is the speed at which infrastructure and investment approvals are granted. China's single-party system enables swift decisions, which is critical for large-scale infrastructure projects. For instance, the construction of new highways, railways, and facilities can be executed in a matter of months, thanks to less bureaucratic interference. In contrast, India faces substantial delays due to multiple layers of approval involving state and local governments. This sluggish approach not only hampers development but also erodes investor confidence.\n\nAdditionally, the dynamic between central and local governments in each country greatly influences economic initiatives. In China, local governments are often incentivized to perform under the guidance of central mandates, fostering a cohesive approach to development. However, local governments in India frequently act with a degree of autonomy that can lead to inconsistent policy execution across states. This fragmentation can stifle localized economic initiatives, as different regions may pursue divergent paths depending on local circumstances rather than a unified national strategy.\n\nIn summary, the stark differences in governance mechanisms and bureaucratic efficiency between India and China have profound implications for their economic trajectories. While China benefits from centralized control and rapid decision-making, India's complex governance structure and corruption challenges hinder its ability to achieve the same level of economic progress."),
#   (5,
#    "## Technical Innovation and Investment Climate\n\nIndia and China have pursued distinct paths regarding technological innovation and foreign direct investment (FDI), which has significantly influenced their respective economic trajectories.\n\n**Startup and Innovation Ecosystems:**\nIn China, the government has implemented comprehensive support mechanisms for startups, including substantial funding, infrastructure, and mentorship. This has resulted in a vibrant innovation ecosystem, particularly in tech hubs like Shenzhen. The Chinese government actively promotes research and development (R&D), incentivizing companies to prioritize innovation through grants and tax breaks. Conversely, India is catching up but still lacks the same breadth of support systems. While the Indian government has launched initiatives such as Startup India and Digital India, challenges remain related to bureaucratic red tape and limited access to venture capital for early-stage companies.\n\n**Foreign Direct Investment Policies:**\nWhen comparing FDI policies, China's approach is characterized by its pro-active stance, offering considerable incentives for foreign companies. It consistently ranks high in ease of doing business due to streamlined regulations, robust infrastructure, and favorable market conditions. According to the World Bank, China's reforms have led to a Business-Friendly Environment that attracts large volumes of FDI. Meanwhile, India has improved its rankings but still faces obstacles that hinder investment. Issues include complex taxation systems, regulatory hurdles, and a less developed infrastructure in certain areas, making it challenging for foreign investors to establish and grow their businesses efficiently.\n\n**Government Initiatives:**\nGovernment initiatives like Make in India, which aims to transform India into a global manufacturing hub by encouraging production, demonstrate India’s commitment to bolstering its industrial base. However, the initiative has faced criticism regarding its implementation and effectiveness. China's government strategies, including substantial investment in AI, 5G, and advanced manufacturing technologies, reflect a clear prioritization of tech advancement. This focus has enabled China to achieve significant milestones in areas such as electric vehicles and telecommunications, further consolidating its position as a global leader in technology.\n\nIn summary, while both India and China recognize the importance of technological innovation and foreign investment for economic growth, the execution and support of these initiatives vary greatly. China's integrated and aggressive approach has yielded rapid advancements and a strong FDI influx, while India's evolving ecosystem faces hurdles that slow its growth potential. Continued evolution in these areas is critical for India's future competitiveness on the global stage."),
#   (6,
#    "## Examining Social and Cultural Factors\n\nThe economic divergence between India and China can be significantly attributed to social and cultural factors that shape entrepreneurship, demographic trends, and gender roles in both countries.\n\n### Attitudes Towards Entrepreneurship\n\nIn China, there is a strong cultural emphasis on entrepreneurship, fostering an environment where starting and scaling businesses is both encouraged and celebrated. The Chinese government supports this through favorable policies, funding initiatives, and a robust infrastructure that enables businesses to thrive. Conversely, India's social fabric often exhibits hesitance toward entrepreneurship, influenced by traditional values and a higher perceived risk associated with starting new ventures. This discrepancy affects innovation and the rate of new business formation, resulting in slower overall economic growth in India compared to China.\n\n### Demographic Trends\n\nDemographic trends highlight stark differences in population dynamics that further fuel economic divergence. China's population growth has slowed considerably, leading to an aging population that poses long-term economic challenges. However, this demographic shift has also led to increased productivity as older workers contribute their experience. In contrast, India enjoys a youthful population with a median age of around 28, presenting significant potential for economic expansion. Yet, this opportunity is hindered by a lack of infrastructure and adequate investments in education and skill development, which are critical for harnessing the potential of its young workforce.\n\n### Impact of Gender Roles\n\nGender roles in both countries have a profound impact on economic participation. In China, there has been substantial progress in gender equality, which has led to higher participation rates of women in the workforce. This enhancement has bolstered the economy by increasing the talent pool and diversifying skills within various sectors. In India, traditional gender norms continue to restrict women’s participation. Despite initiatives aimed at improving women’s workforce inclusion, challenges such as societal expectations and safety concerns persist. This underutilization of one half of the population not only slows economic growth but also perpetuates inequalities that prevent India from catching up with China.\n\n### Conclusion\n\nIn summary, socio-cultural factors significantly influence the economic trajectories of India and China. By fostering entrepreneurship, addressing demographic challenges, and promoting gender equality, India has the potential to improve its economic standing relative to China. Understanding these social and cultural dimensions is crucial for policymakers and economists as they strategize for India's development future."),
#   (7,
#    "## Identifying Future Opportunities and Challenges\n\nAs India and China continue their distinct economic trajectories, examining potential areas for collaboration can reveal strategic advantages that may benefit both nations. \n\n### Collaboration over Competition\n\nWhile often seen as competitors, India and China could explore numerous avenues for cooperation, particularly in trade and technology exchange. For instance, both nations are emerging markets with vast consumer bases, making them ideal partners in sectors such as renewable energy, pharmaceuticals, and information technology. Sharing innovations in these industries can yield mutual benefits; India might leverage China's advancements in manufacturing and logistics, while China can harness India's strengths in software development and digital services. Facilitating dialogues between trade councils could lead to reduced tariffs and improved access to each other's markets, amplifying economic growth momentum.\n\n### Navigating Challenges\n\nNonetheless, both countries face significant challenges that could hinder their economic progress. Climate change poses a formidable threat, affecting agriculture, food security, and overall economic stability. India, struggling with severe air pollution and water scarcity, will need to adopt sustainable practices to mitigate these impacts. Similarly, China faces increasing scrutiny over its environmental policies and the need to transition to a greener economy. Emphasizing collaboration in sustainability initiatives, such as joint research projects focusing on clean energy technologies, can help both nations address these challenges while creating new job opportunities.\n\nResource depletion is another pressing concern. With ever-growing populations and development needs, the pressure on natural resources is immense. Water scarcity, in particular, is a critical issue for both countries, requiring innovative solutions and enhanced management practices. Cooperation in water conservation efforts, through knowledge sharing, can provide insights into efficient usage models applicable in both regions.\n\n### Prospects for Sustained Growth\n\nAs global economic trends shift towards more inclusive and sustainable practices, both India and China must adapt their approaches to ensure sustained growth. Factors like the rise of digital economies and changing consumer behaviors in response to globalization provide new avenues for market expansion. For instance, India's burgeoning start-up ecosystem offers significant potential for growth in tech-driven sectors.\n\nChanging global dynamics, such as a renewed focus on supply chain resilience after the recent global disruptions, presents an opportunity for both nations to recalibrate their manufacturing strategies. India could attract investment from companies looking to diversify their supply chains, while China must leverage its existing infrastructure and expertise to stay competitive.\n\nIn conclusion, the path ahead is not devoid of hurdles for both India and China. However, embracing strategic collaboration, addressing environmental challenges, and adapting to evolving global trends can pave the way for sustainable economic development in the coming decades. As they navigate this landscape, the choices made today will significantly influence their trajectories in the years ahead."),
#   (1,
#    "## Assessing Historical Economic Policies\n\nIndia's economic policies post-independence were largely characterized by a focus on self-reliance and protectionism. This approach aimed to build a robust domestic economy shielded from foreign competition. Key aspects included the establishment of a licensing regime, public sector dominance, and import substitution strategies. However, this protectionist framework often stifled growth, leading to inefficiencies and a slow rate of industrialization.\n\nIn contrast, China's economic reforms, which began in the late 1970s under Deng Xiaoping, marked a radical shift towards market liberalization. These reforms dismantled the centralized planning system and allowed for increased foreign investment, private enterprise, and a focus on export-led growth. The establishment of Special Economic Zones (SEZs) encouraged global trade participation and technology transfer, fundamentally transforming China’s economic landscape.\n\nA crucial point of difference lies in the state involvement in the economy. In India, the government played a restrictive role, often portraying the private sector as a secondary player. Conversely, China embraced a more dynamic approach where the state acted as a catalyst, promoting both public and private sectors while retaining tight control over strategic industries. This dual strategy enabled rapid growth and adaptability in response to global economic changes.\n\nAs a result of these historical economic policies, India's growth has lagged behind China's. The reliance on protectionism restrained competitive advantage, while China's liberalization fostered innovation and productivity. Understanding these contrasting strategies is critical for policymakers and economists as they work to navigate India's future economic development. The lessons learned from these historical contexts will be essential in devising effective policy frameworks that can bolster India's growth trajectory."),
#   (2,
#    "## Evaluating Infrastructure Development\n\nInfrastructure development plays a crucial role in shaping the economic growth trajectory of nations. When comparing India and China, significant differences in the scale and quality of transportation networks are evident, which profoundly impact business operations and economic activity.\n\nChina has massively invested in its transportation infrastructure, resulting in an extensive and high-quality network of roads, railways, and ports. The country boasts the longest high-speed rail network in the world, enabling rapid movement of goods and people across vast distances. This network is complemented by an efficient system of roads and significant investment in port facilities, which enhances China’s capacity for international trade. Consequently, these advancements have facilitated industrial growth, ensuring swift access to markets and resources.\n\nConversely, India’s transportation infrastructure lags behind in both scale and quality. Although India has made strides in improving its road and railway networks, challenges remain in maintenance and expansion. Road congestion and inadequate rail connectivity often hinder the efficient movement of goods. Ports, which are vital for international trade, also require modernization to handle increasing cargo volumes. This disparity in infrastructure limits India's ability to compete effectively on a global scale.\n\nUrbanization rates further highlight the differences in development strategies between the two nations. China's rapid urbanization has been underpinned by significant government investment in infrastructure, enabling cities to support industrialization effectively. Urban centers in China have become hubs of economic activity, equipped with modern facilities and services that attract businesses and investments. In contrast, India's urbanization has faced challenges such as inadequate infrastructure and planning. As cities expand, the strain on existing infrastructure often leads to inefficiencies that impede economic growth.\n\nFurthermore, the reliability of power supply and telecommunications readiness are essential components of a robust infrastructure. In China, the government's focus on developing a stable power grid and modern telecommunications has fostered a conducive environment for business growth. Companies benefit from reliable electricity and cutting-edge communication technologies, allowing them to operate efficiently. In India, however, power outages are still relatively common, with a significant proportion of the population lacking access to consistent electricity. Telecommunications infrastructure, while improving, is unevenly distributed, impacting the growth potential of businesses, especially in rural areas.\n\nIn summary, the disparities in transportation networks, urbanization support, and essential utilities between India and China illustrate the challenges that India faces in catching up economically. Progress in these areas will be crucial for India to enhance its industrial capabilities and strengthen its position in the global economy."),
#   (3,
#    "## Understanding Human Capital Development\n\nHuman capital development plays a crucial role in the economic trajectories of countries, especially concerning education, skill development, and public health. When we compare India and China, the disparities in these areas significantly contribute to their varying economic progress.\n\n### Literacy Rates and Educational Attainment\n\nLiteracy rates and educational attainment levels serve as foundational pillars for workforce capability. According to recent statistics, China's literacy rate exceeds 96%, while India's is around 74%. This fundamental difference facilitates higher levels of educational attainment in China, where more than 50% of the population has completed higher secondary education. In contrast, India's educational system struggles with high dropout rates, particularly in rural areas. These disparities manifest in the workforce; a more educated and skilled workforce enhances productivity, innovation, and economic growth.\n\n### Vocational Training Programs\n\nVocational training programs are another critical aspect influencing human capital development. China has effectively integrated vocational training into its economic sectors, promoting skill development aligned with labor market needs. The alignment between education and economic demand helps China produce a workforce that is ready for both manufacturing and technology-driven industries. Conversely, India has made strides through initiatives like the Skill India Mission; however, the implementation and reach of these programs vary significantly. Many graduates from vocational training programs struggle to find adequate job placements, indicating a disconnect between training and real workforce requirements.\n\n### Public Health Implications\n\nPublic health significantly affects human capital productivity and workforce participation. China invests heavily in healthcare infrastructure, leading to better health outcomes, lower disease burden, and increased life expectancy. In comparison, India's public health system faces challenges, including inadequate access to healthcare services and higher prevalence of malnutrition among children. Poor health hampers workforce participation, as unhealthy individuals are less likely to contribute effectively to economic activities. This results not only in a decline in productivity but also in higher healthcare costs for families and the government.\n\nIn conclusion, the combined effect of literacy, vocational training, and public health illustrates why India currently lags behind China in economic development. Addressing these human capital challenges is essential for India to enhance its workforce capabilities, thereby fostering economic growth and improving living standards."),
#   (4,
#    "## Analyzing Governance and Bureaucratic Efficiency\n\nGovernance and bureaucratic efficiency play critical roles in shaping economic trajectories, particularly in contrasting contexts like India and China. Understanding the differences in government effectiveness and perceptions of corruption reveals why China has often outpaced India in economic progress.\n\nIn China, the government's centralized control allows for more streamlined decision-making. The ruling Communist Party prioritizes economic growth and has a track record of rapid, effective policy implementation. Conversely, India's multi-tiered governance system often results in bureaucratic delays and red tape. The perception of widespread corruption in India further complicates efforts to align public policy with economic objectives. According to various studies, many investors cite corruption as a barrier to business, making them hesitant to commit to long-term investments in the Indian market.\n\nAnother significant aspect is the speed at which infrastructure and investment approvals are granted. China's single-party system enables swift decisions, which is critical for large-scale infrastructure projects. For instance, the construction of new highways, railways, and facilities can be executed in a matter of months, thanks to less bureaucratic interference. In contrast, India faces substantial delays due to multiple layers of approval involving state and local governments. This sluggish approach not only hampers development but also erodes investor confidence.\n\nAdditionally, the dynamic between central and local governments in each country greatly influences economic initiatives. In China, local governments are often incentivized to perform under the guidance of central mandates, fostering a cohesive approach to development. However, local governments in India frequently act with a degree of autonomy that can lead to inconsistent policy execution across states. This fragmentation can stifle localized economic initiatives, as different regions may pursue divergent paths depending on local circumstances rather than a unified national strategy.\n\nIn summary, the stark differences in governance mechanisms and bureaucratic efficiency between India and China have profound implications for their economic trajectories. While China benefits from centralized control and rapid decision-making, India's complex governance structure and corruption challenges hinder its ability to achieve the same level of economic progress."),
#   (5,
#    "## Technical Innovation and Investment Climate\n\nIndia and China have pursued distinct paths regarding technological innovation and foreign direct investment (FDI), which has significantly influenced their respective economic trajectories.\n\n**Startup and Innovation Ecosystems:**\nIn China, the government has implemented comprehensive support mechanisms for startups, including substantial funding, infrastructure, and mentorship. This has resulted in a vibrant innovation ecosystem, particularly in tech hubs like Shenzhen. The Chinese government actively promotes research and development (R&D), incentivizing companies to prioritize innovation through grants and tax breaks. Conversely, India is catching up but still lacks the same breadth of support systems. While the Indian government has launched initiatives such as Startup India and Digital India, challenges remain related to bureaucratic red tape and limited access to venture capital for early-stage companies.\n\n**Foreign Direct Investment Policies:**\nWhen comparing FDI policies, China's approach is characterized by its pro-active stance, offering considerable incentives for foreign companies. It consistently ranks high in ease of doing business due to streamlined regulations, robust infrastructure, and favorable market conditions. According to the World Bank, China's reforms have led to a Business-Friendly Environment that attracts large volumes of FDI. Meanwhile, India has improved its rankings but still faces obstacles that hinder investment. Issues include complex taxation systems, regulatory hurdles, and a less developed infrastructure in certain areas, making it challenging for foreign investors to establish and grow their businesses efficiently.\n\n**Government Initiatives:**\nGovernment initiatives like Make in India, which aims to transform India into a global manufacturing hub by encouraging production, demonstrate India’s commitment to bolstering its industrial base. However, the initiative has faced criticism regarding its implementation and effectiveness. China's government strategies, including substantial investment in AI, 5G, and advanced manufacturing technologies, reflect a clear prioritization of tech advancement. This focus has enabled China to achieve significant milestones in areas such as electric vehicles and telecommunications, further consolidating its position as a global leader in technology.\n\nIn summary, while both India and China recognize the importance of technological innovation and foreign investment for economic growth, the execution and support of these initiatives vary greatly. China's integrated and aggressive approach has yielded rapid advancements and a strong FDI influx, while India's evolving ecosystem faces hurdles that slow its growth potential. Continued evolution in these areas is critical for India's future competitiveness on the global stage."),
#   (6,
#    "## Examining Social and Cultural Factors\n\nThe economic divergence between India and China can be significantly attributed to social and cultural factors that shape entrepreneurship, demographic trends, and gender roles in both countries.\n\n### Attitudes Towards Entrepreneurship\n\nIn China, there is a strong cultural emphasis on entrepreneurship, fostering an environment where starting and scaling businesses is both encouraged and celebrated. The Chinese government supports this through favorable policies, funding initiatives, and a robust infrastructure that enables businesses to thrive. Conversely, India's social fabric often exhibits hesitance toward entrepreneurship, influenced by traditional values and a higher perceived risk associated with starting new ventures. This discrepancy affects innovation and the rate of new business formation, resulting in slower overall economic growth in India compared to China.\n\n### Demographic Trends\n\nDemographic trends highlight stark differences in population dynamics that further fuel economic divergence. China's population growth has slowed considerably, leading to an aging population that poses long-term economic challenges. However, this demographic shift has also led to increased productivity as older workers contribute their experience. In contrast, India enjoys a youthful population with a median age of around 28, presenting significant potential for economic expansion. Yet, this opportunity is hindered by a lack of infrastructure and adequate investments in education and skill development, which are critical for harnessing the potential of its young workforce.\n\n### Impact of Gender Roles\n\nGender roles in both countries have a profound impact on economic participation. In China, there has been substantial progress in gender equality, which has led to higher participation rates of women in the workforce. This enhancement has bolstered the economy by increasing the talent pool and diversifying skills within various sectors. In India, traditional gender norms continue to restrict women’s participation. Despite initiatives aimed at improving women’s workforce inclusion, challenges such as societal expectations and safety concerns persist. This underutilization of one half of the population not only slows economic growth but also perpetuates inequalities that prevent India from catching up with China.\n\n### Conclusion\n\nIn summary, socio-cultural factors significantly influence the economic trajectories of India and China. By fostering entrepreneurship, addressing demographic challenges, and promoting gender equality, India has the potential to improve its economic standing relative to China. Understanding these social and cultural dimensions is crucial for policymakers and economists as they strategize for India's development future."),
#   (7,
#    "## Identifying Future Opportunities and Challenges\n\nAs India and China continue their distinct economic trajectories, examining potential areas for collaboration can reveal strategic advantages that may benefit both nations. \n\n### Collaboration over Competition\n\nWhile often seen as competitors, India and China could explore numerous avenues for cooperation, particularly in trade and technology exchange. For instance, both nations are emerging markets with vast consumer bases, making them ideal partners in sectors such as renewable energy, pharmaceuticals, and information technology. Sharing innovations in these industries can yield mutual benefits; India might leverage China's advancements in manufacturing and logistics, while China can harness India's strengths in software development and digital services. Facilitating dialogues between trade councils could lead to reduced tariffs and improved access to each other's markets, amplifying economic growth momentum.\n\n### Navigating Challenges\n\nNonetheless, both countries face significant challenges that could hinder their economic progress. Climate change poses a formidable threat, affecting agriculture, food security, and overall economic stability. India, struggling with severe air pollution and water scarcity, will need to adopt sustainable practices to mitigate these impacts. Similarly, China faces increasing scrutiny over its environmental policies and the need to transition to a greener economy. Emphasizing collaboration in sustainability initiatives, such as joint research projects focusing on clean energy technologies, can help both nations address these challenges while creating new job opportunities.\n\nResource depletion is another pressing concern. With ever-growing populations and development needs, the pressure on natural resources is immense. Water scarcity, in particular, is a critical issue for both countries, requiring innovative solutions and enhanced management practices. Cooperation in water conservation efforts, through knowledge sharing, can provide insights into efficient usage models applicable in both regions.\n\n### Prospects for Sustained Growth\n\nAs global economic trends shift towards more inclusive and sustainable practices, both India and China must adapt their approaches to ensure sustained growth. Factors like the rise of digital economies and changing consumer behaviors in response to globalization provide new avenues for market expansion. For instance, India's burgeoning start-up ecosystem offers significant potential for growth in tech-driven sectors.\n\nChanging global dynamics, such as a renewed focus on supply chain resilience after the recent global disruptions, presents an opportunity for both nations to recalibrate their manufacturing strategies. India could attract investment from companies looking to diversify their supply chains, while China must leverage its existing infrastructure and expertise to stay competitive.\n\nIn conclusion, the path ahead is not devoid of hurdles for both India and China. However, embracing strategic collaboration, addressing environmental challenges, and adapting to evolving global trends can pave the way for sustainable economic development in the coming decades. As they navigate this landscape, the choices made today will significantly influence their trajectories in the years ahead.")],
#  'merged_md': "# Comparative Analysis: India's Development Trajectory vs. China's\n\n## Assessing Historical Economic Policies\n\nIndia's economic policies post-independence were largely characterized by a focus on self-reliance and protectionism. This approach aimed to build a robust domestic economy shielded from foreign competition. Key aspects included the establishment of a licensing regime, public sector dominance, and import substitution strategies. However, this protectionist framework often stifled growth, leading to inefficiencies and a slow rate of industrialization.\n\nIn contrast, China's economic reforms, which began in the late 1970s under Deng Xiaoping, marked a radical shift towards market liberalization. These reforms dismantled the centralized planning system and allowed for increased foreign investment, private enterprise, and a focus on export-led growth. The establishment of Special Economic Zones (SEZs) encouraged global trade participation and technology transfer, fundamentally transforming China’s economic landscape.\n\nA crucial point of difference lies in the state involvement in the economy. In India, the government played a restrictive role, often portraying the private sector as a secondary player. Conversely, China embraced a more dynamic approach where the state acted as a catalyst, promoting both public and private sectors while retaining tight control over strategic industries. This dual strategy enabled rapid growth and adaptability in response to global economic changes.\n\nAs a result of these historical economic policies, India's growth has lagged behind China's. The reliance on protectionism restrained competitive advantage, while China's liberalization fostered innovation and productivity. Understanding these contrasting strategies is critical for policymakers and economists as they work to navigate India's future economic development. The lessons learned from these historical contexts will be essential in devising effective policy frameworks that can bolster India's growth trajectory.\n\n## Evaluating Infrastructure Development\n\nInfrastructure development plays a crucial role in shaping the economic growth trajectory of nations. When comparing India and China, significant differences in the scale and quality of transportation networks are evident, which profoundly impact business operations and economic activity.\n\nChina has massively invested in its transportation infrastructure, resulting in an extensive and high-quality network of roads, railways, and ports. The country boasts the longest high-speed rail network in the world, enabling rapid movement of goods and people across vast distances. This network is complemented by an efficient system of roads and significant investment in port facilities, which enhances China’s capacity for international trade. Consequently, these advancements have facilitated industrial growth, ensuring swift access to markets and resources.\n\nConversely, India’s transportation infrastructure lags behind in both scale and quality. Although India has made strides in improving its road and railway networks, challenges remain in maintenance and expansion. Road congestion and inadequate rail connectivity often hinder the efficient movement of goods. Ports, which are vital for international trade, also require modernization to handle increasing cargo volumes. This disparity in infrastructure limits India's ability to compete effectively on a global scale.\n\nUrbanization rates further highlight the differences in development strategies between the two nations. China's rapid urbanization has been underpinned by significant government investment in infrastructure, enabling cities to support industrialization effectively. Urban centers in China have become hubs of economic activity, equipped with modern facilities and services that attract businesses and investments. In contrast, India's urbanization has faced challenges such as inadequate infrastructure and pl ...
#  'md_with_placeholders': "# Comparative Analysis: India's Development Trajectory vs. China's\n\n## Assessing Historical Economic Policies\n\nIndia's economic policies post-independence were largely characterized by a focus on self-reliance and protectionism. This approach aimed to build a robust domestic economy shielded from foreign competition. Key aspects included the establishment of a licensing regime, public sector dominance, and import substitution strategies. However, this protectionist framework often stifled growth, leading to inefficiencies and a slow rate of industrialization.\n\nIn contrast, China's economic reforms, which began in the late 1970s under Deng Xiaoping, marked a radical shift towards market liberalization. These reforms dismantled the centralized planning system and allowed for increased foreign investment, private enterprise, and a focus on export-led growth. The establishment of Special Economic Zones (SEZs) encouraged global trade participation and technology transfer, fundamentally transforming China’s economic landscape.\n\nA crucial point of difference lies in the state involvement in the economy. In India, the government played a restrictive role, often portraying the private sector as a secondary player. Conversely, China embraced a more dynamic approach where the state acted as a catalyst, promoting both public and private sectors while retaining tight control over strategic industries. This dual strategy enabled rapid growth and adaptability in response to global economic changes.\n\nAs a result of these historical economic policies, India's growth has lagged behind China's. The reliance on protectionism restrained competitive advantage, while China's liberalization fostered innovation and productivity. Understanding these contrasting strategies is critical for policymakers and economists as they work to navigate India's future economic development. The lessons learned from these historical contexts will be essential in devising effective policy frameworks that can bolster India's growth trajectory.\n\n## Evaluating Infrastructure Development\n\nInfrastructure development plays a crucial role in shaping the economic growth trajectory of nations. When comparing India and China, significant differences in the scale and quality of transportation networks are evident, which profoundly impact business operations and economic activity.\n\nChina has massively invested in its transportation infrastructure, resulting in an extensive and high-quality network of roads, railways, and ports. The country boasts the longest high-speed rail network in the world, enabling rapid movement of goods and people across vast distances. This network is complemented by an efficient system of roads and significant investment in port facilities, which enhances China’s capacity for international trade. Consequently, these advancements have facilitated industrial growth, ensuring swift access to markets and resources.\n\nConversely, India’s transportation infrastructure lags behind in both scale and quality. Although India has made strides in improving its road and railway networks, challenges remain in maintenance and expansion. Road congestion and inadequate rail connectivity often hinder the efficient movement of goods. Ports, which are vital for international trade, also require modernization to handle increasing cargo volumes. This disparity in infrastructure limits India's ability to compete effectively on a global scale.\n\nUrbanization rates further highlight the differences in development strategies between the two nations. China's rapid urbanization has been underpinned by significant government investment in infrastructure, enabling cities to support industrialization effectively. Urban centers in China have become hubs of economic activity, equipped with modern facilities and services that attract businesses and investments. In contrast, India's urbanization has faced challenges such as inadequate infrastruc ...
#  'image_specs': [{'placeholder': '[[IMAGE_1]]',
#    'filename': 'india_china_comparison_chart.png',
#    'alt': 'Comparison chart of economic rankings between India and China',
#    'caption': 'Chart comparing key economic indicators between India and China.',
#    'prompt': 'A comparison chart showcasing key economic indicators such as GDP, literacy rates, and infrastructure development between India and China.',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_2]]',
#    'filename': 'infrastructure_development_in_india_china.png',
#    'alt': 'Infographic on infrastructure development in India vs China',
#    'caption': 'Infographic highlighting the differences in infrastructure development between India and China.',
#    'prompt': 'Infographic illustrating the differences in transportation, urbanization, and utilities in India and China.',
#    'size': '1024x1024',
#    'quality': 'high'},
#   {'placeholder': '[[IMAGE_3]]',
#    'filename': 'human_capital_development_india_china.png',
#    'alt': 'Chart showing human capital development factors in India and China',
#    'caption': 'Chart detailing human capital development factors such as education and health in India and China.',
#    'prompt': 'A visual representation comparing human capital development factors such as literacy rates, vocational training, and public health outcomes in India and China.',
#    'size': '1024x1024',
#    'quality': 'high'}],
#  'final': "# Comparative Analysis: India's Development Trajectory vs. China's\n\n## Assessing Historical Economic Policies\n\nIndia's economic policies post-independence were largely characterized by a focus on self-reliance and protectionism. This approach aimed to build a robust domestic economy shielded from foreign competition. Key aspects included the establishment of a licensing regime, public sector dominance, and import substitution strategies. However, this protectionist framework often stifled growth, leading to inefficiencies and a slow rate of industrialization.\n\nIn contrast, China's economic reforms, which began in the late 1970s under Deng Xiaoping, marked a radical shift towards market liberalization. These reforms dismantled the centralized planning system and allowed for increased foreign investment, private enterprise, and a focus on export-led growth. The establishment of Special Economic Zones (SEZs) encouraged global trade participation and technology transfer, fundamentally transforming China’s economic landscape.\n\nA crucial point of difference lies in the state involvement in the economy. In India, the government played a restrictive role, often portraying the private sector as a secondary player. Conversely, China embraced a more dynamic approach where the state acted as a catalyst, promoting both public and private sectors while retaining tight control over strategic industries. This dual strategy enabled rapid growth and adaptability in response to global economic changes.\n\nAs a result of these historical economic policies, India's growth has lagged behind China's. The reliance on protectionism restrained competitive advantage, while China's liberalization fostered innovation and productivity. Understanding these contrasting strategies is critical for policymakers and economists as they work to navigate India's future economic development. The lessons learned from these historical contexts will be essential in devising effective policy frameworks that can bolster India's growth trajectory.\n\n## Evaluating Infrastructure Development\n\nInfrastructure development plays a crucial role in shaping the economic growth trajectory of nations. When comparing India and China, significant differences in the scale and quality of transportation networks are evident, which profoundly impact business operations and economic activity.\n\nChina has massively invested in its transportation infrastructure, resulting in an extensive and high-quality network of roads, railways, and ports. The country boasts the longest high-speed rail network in the world, enabling rapid movement of goods and people across vast distances. This network is complemented by an efficient system of roads and significant investment in port facilities, which enhances China’s capacity for international trade. Consequently, these advancements have facilitated industrial growth, ensuring swift access to markets and resources.\n\nConversely, India’s transportation infrastructure lags behind in both scale and quality. Although India has made strides in improving its road and railway networks, challenges remain in maintenance and expansion. Road congestion and inadequate rail connectivity often hinder the efficient movement of goods. Ports, which are vital for international trade, also require modernization to handle increasing cargo volumes. This disparity in infrastructure limits India's ability to compete effectively on a global scale.\n\nUrbanization rates further highlight the differences in development strategies between the two nations. China's rapid urbanization has been underpinned by significant government investment in infrastructure, enabling cities to support industrialization effectively. Urban centers in China have become hubs of economic activity, equipped with modern facilities and services that attract businesses and investments. In contrast, India's urbanization has faced challenges such as inadequate infrastructure and planni ...

# %%
# Out:
# Sure! Artificial Intelligence, or AI, is a technology that enables computers and machines to perform tasks that usually require human intelligence. This includes things like understanding language, recognizing images, solving problems, and making decisions.
#
# Think of AI as a way for computers to "think" and "learn" from information, much like how humans do. For example, when you ask a voice assistant (like Siri or Alexa) a question, it uses AI to understand your words and provide a response. AI can also learn from experience, improving its ability to perform tasks over time.

# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[66], line 10
#       4 client = OpenAI(
#       5     api_key="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"
#       6 )
#       8 prompt = "A futuristic AI robot working on a laptop, digital art style"
# ---> 10 result = client.images.generate(
#      11     model="gpt-image-1-mini",
#      12     prompt=prompt,
#      13     size="1024x1024"
#      14 )
#      16 # Decode and save image
#      17 image_base64 = result.data[0].b64_json
#
# File c:\Users\user\Desktop\LG\myenv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\user\Desktop\LG\myenv\Lib\site-packages\openai\resources\images.py:891, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     863 @required_args(["prompt"], ["prompt", "stream"])
#     864 def generate(
#     865     self,
#    (...)    889     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     890 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# --> 891     return self._post(
#     892         "/images/generations",
#     893         body=maybe_transform(
#     894             {
#     895                 "prompt": prompt,
#     896                 "background": background,
#     897                 "model": model,
#     898                 "moderation": moderation,
#     899                 "n": n,
#     900                 "output_compression": output_compression,
#     901                 "output_format": output_format,
#     902                 "partial_images": partial_images,
#     903                 "quality": quality,
#     904                 "response_format": response_format,
#     905                 "size": size,
#     906                 "stream": stream,
#     907                 "style": style,
#     908                 "user": user,
#     909             },
#     910             image_generate_params.ImageGenerateParamsStreaming
#     911             if stream
#     912             else image_generate_params.ImageGenerateParamsNonStreaming,
#     913         ),
#     914         options=make_request_options(
#     915             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     916         ),
#     917         cast_to=ImagesResponse,
#     918         stream=stream or False,
#     919         stream_cls=Stream[ImageGenStreamEvent],
#     920     )
#
# File c:\Users\user\Desktop\LG\myenv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\user\Desktop\LG\myenv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# PermissionDeniedError: Error code: 403 - {'error': {'message': 'Project `proj_md2UW8GCERdH7k8ezqBqCnVW` does not have access to model `gpt-image-1-mini`', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
